# %% [markdown]
# <a href="https://colab.research.google.com/github/Tikakiku/RoboticsTasks/blob/main/Tugas_13_Robotika_Convolutional_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Convolutional Neural Network
#
# ###Nama : Ratika Dwi Anggraini
# ###Kelas : TK4406
# ###IM : 1103201250

# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip

  #import dataset Chessman-image-dataset dan download dalam bentuk zip
# Out:
# --2024-01-05 19:55:18--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-05 19:55:18--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   274MB/s    in 0.2s
#
# 2024-01-05 19:55:21 (274 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Ekstrak dataset menggunakan zipfile

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Lihat direktori dataset
# Out:
# ['Knight', 'King', 'Queen', 'Pawn', 'Bishop', 'Rook']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Menghitung total data tiap direktori
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)
# Melihat salah satu gambar pada dataset

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
) #set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 16s - loss: 1.8811 - accuracy: 0.1563 - val_loss: 1.7870 - val_accuracy: 0.1923 - 16s/epoch - 259ms/step
# Epoch 2/50
# 63/63 - 8s - loss: 1.7897 - accuracy: 0.1723 - val_loss: 1.7831 - val_accuracy: 0.1731 - 8s/epoch - 135ms/step
# Epoch 3/50
# 63/63 - 7s - loss: 1.7643 - accuracy: 0.2405 - val_loss: 1.7500 - val_accuracy: 0.2308 - 7s/epoch - 109ms/step
# Epoch 4/50
# 63/63 - 7s - loss: 1.7163 - accuracy: 0.2625 - val_loss: 1.6984 - val_accuracy: 0.2885 - 7s/epoch - 117ms/step
# Epoch 5/50
# 63/63 - 8s - loss: 1.7162 - accuracy: 0.2986 - val_loss: 1.7526 - val_accuracy: 0.2885 - 8s/epoch - 129ms/step
# Epoch 6/50
# 63/63 - 7s - loss: 1.6407 - accuracy: 0.3327 - val_loss: 1.6207 - val_accuracy: 0.3462 - 7s/epoch - 117ms/step
# Epoch 7/50
# 63/63 - 8s - loss: 1.5891 - accuracy: 0.3727 - val_loss: 1.6719 - val_accuracy: 0.2885 - 8s/epoch - 122ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 1.5574 - accuracy: 0.3547 - val_loss: 1.6134 - val_accuracy: 0.4038 - 9s/epoch - 140ms/step
# Epoch 9/50
# 63/63 - 7s - loss: 1.5214 - accuracy: 0.4068 - val_loss: 1.4971 - val_accuracy: 0.5192 - 7s/epoch - 108ms/step
# Epoch 10/50
# 63/63 - 8s - loss: 1.5200 - accuracy: 0.3848 - val_loss: 1.5831 - val_accuracy: 0.3462 - 8s/epoch - 125ms/step
# Epoch 11/50
# 63/63 - 8s - loss: 1.3938 - accuracy: 0.4389 - val_loss: 1.5183 - val_accuracy: 0.4038 - 8s/epoch - 128ms/step
# Epoch 12/50
# 63/63 - 7s - loss: 1.4088 - accuracy: 0.4349 - val_loss: 1.5067 - val_accuracy: 0.3654 - 7s/epoch - 109ms/step
# Epoch 13/50
# 63/63 - 8s - loss: 1.3880 - accuracy: 0.4770 - val_loss: 1.5506 - val_accuracy: 0.4231 - 8s/epoch - 127ms/step
# Epoch 14/50
# 63/63 - 7s - loss: 1.3112 - accuracy: 0.4669 - val_loss: 1.4278 - val_accuracy: 0.4615 - 7s/epoch - 119ms/step
# Epoch 15/50
# 63/63 - 8s - loss: 1.3125 - accuracy: 0.4810 - val_loss: 1.5594 - val_accuracy: 0.3846 - 8s/epoch - 121ms/step
# Epoch 16/50
# 63/63 - 8s - loss: 1.3008 - accuracy: 0.5030 - val_loss: 1.5233 - val_accuracy: 0.3846 - 8s/epoch - 129ms/step
# Epoch 17/50
# 63/63 - 7s - loss: 1.2391 - accuracy: 0.5371 - val_loss: 1.4931 - val_accuracy: 0.4423 - 7s/epoch - 109ms/step
# Epoch 18/50
# 63/63 - 7s - loss: 1.1935 - accuracy: 0.5311 - val_loss: 1.6308 - val_accuracy: 0.3462 - 7s/epoch - 107ms/step
# Epoch 19/50
# 63/63 - 7s - loss: 1.1753 - accuracy: 0.5531 - val_loss: 1.5050 - val_accuracy: 0.4808 - 7s/epoch - 117ms/step
# Epoch 20/50
# 63/63 - 8s - loss: 1.1372 - accuracy: 0.5391 - val_loss: 1.4692 - val_accuracy: 0.4808 - 8s/epoch - 126ms/step
# Epoch 21/50
# 63/63 - 8s - loss: 1.0943 - accuracy: 0.5872 - val_loss: 1.5098 - val_accuracy: 0.4615 - 8s/epoch - 125ms/step
# Epoch 22/50
# 63/63 - 7s - loss: 1.1256 - accuracy: 0.5872 - val_loss: 1.5709 - val_accuracy: 0.3269 - 7s/epoch - 113ms/step
# Epoch 23/50
# 63/63 - 8s - loss: 1.1066 - accuracy: 0.5591 - val_loss: 1.6585 - val_accuracy: 0.3269 - 8s/epoch - 126ms/step
# Epoch 24/50
# 63/63 - 8s - loss: 1.0162 - accuracy: 0.5972 - val_loss: 1.4657 - val_accuracy: 0.3654 - 8s/epoch - 124ms/step
# Epoch 25/50
# 63/63 - 7s - loss: 1.0299 - accuracy: 0.6152 - val_loss: 1.5402 - val_accuracy: 0.4231 - 7s/epoch - 114ms/step
# Epoch 26/50
# 63/63 - 8s - loss: 1.0156 - accuracy: 0.6553 - val_loss: 1.5442 - val_accuracy: 0.3077 - 8s/epoch - 130ms/step
# Epoch 27/50
# 63/63 - 8s - loss: 1.0002 - accuracy: 0.6333 - val_loss: 1.4726 - val_accuracy: 0.4423 - 8s/epoch - 126ms/step
# Epoch 28/50
# 63/63 - 7s - loss: 0.9179 - accuracy: 0.6613 - val_loss: 1.4325 - val_accuracy: 0.4231 - 7s/epoch - 113ms/step
# Epoch 29/50
# 63/63 - 8s - loss: 0.8396 - accuracy: 0.6553 - val_loss: 1.4701 - val_accuracy: 0.4231 - 8s/epoch - 130ms/step
# Epoch 30/50
# 63/63 - 8s - loss: 0.9042 - accuracy: 0.6453 - val_loss: 1.5135 - val_accuracy: 0.3654 - 8s/epoch - 124ms/step
# Epoch 31/50
# 63/63 - 7s - loss: 0.7492 - accuracy: 0.7114 - val_loss: 1.3451 - val_accuracy: 0.4615 - 7s/epoch - 110ms/step
# Epoch 32/50
# 63/63 - 7s - loss: 0.8336 - accuracy: 0.6733 - val_loss: 1.4527 - val_accuracy: 0.4038 - 7s/epoch - 113ms/step
# Epoch 33/50
# 63/63 - 8s - loss: 0.7953 - accuracy: 0.7014 - val_loss: 1.4336 - val_accuracy: 0.4615 - 8s/epoch - 132ms/step
# Epoch 34/50
# 63/63 - 7s - loss: 0.8083 - accuracy: 0.6653 - val_loss: 1.6082 - val_accuracy: 0.4231 - 7s/epoch - 111ms/step
# Epoch 35/50
# 63/63 - 8s - loss: 0.6949 - accuracy: 0.7395 - val_loss: 1.5156 - val_accuracy: 0.4231 - 8s/epoch - 129ms/step
# Epoch 36/50
# 63/63 - 8s - loss: 0.7055 - accuracy: 0.7435 - val_loss: 1.9147 - val_accuracy: 0.3269 - 8s/epoch - 124ms/step
# Epoch 37/50
# 63/63 - 7s - loss: 0.7696 - accuracy: 0.7315 - val_loss: 1.6465 - val_accuracy: 0.3846 - 7s/epoch - 113ms/step
# Epoch 38/50
# 63/63 - 8s - loss: 0.6413 - accuracy: 0.7515 - val_loss: 1.5577 - val_accuracy: 0.4231 - 8s/epoch - 129ms/step
# Epoch 39/50
# 63/63 - 7s - loss: 0.6721 - accuracy: 0.7615 - val_loss: 1.5301 - val_accuracy: 0.4423 - 7s/epoch - 118ms/step
# Epoch 40/50
# 63/63 - 8s - loss: 0.6405 - accuracy: 0.7756 - val_loss: 1.6245 - val_accuracy: 0.4808 - 8s/epoch - 132ms/step
# Epoch 41/50
# 63/63 - 8s - loss: 0.7407 - accuracy: 0.7355 - val_loss: 1.6864 - val_accuracy: 0.4038 - 8s/epoch - 126ms/step
# Epoch 42/50
# 63/63 - 7s - loss: 0.5995 - accuracy: 0.7856 - val_loss: 1.7891 - val_accuracy: 0.3462 - 7s/epoch - 108ms/step
# Epoch 43/50
# 63/63 - 8s - loss: 0.5372 - accuracy: 0.8056 - val_loss: 1.6347 - val_accuracy: 0.3654 - 8s/epoch - 130ms/step
# Epoch 44/50
# 63/63 - 7s - loss: 0.5348 - accuracy: 0.8036 - val_loss: 1.6024 - val_accuracy: 0.3654 - 7s/epoch - 118ms/step
# Epoch 45/50
# 63/63 - 8s - loss: 0.5102 - accuracy: 0.8136 - val_loss: 1.5709 - val_accuracy: 0.3654 - 8s/epoch - 120ms/step
# Epoch 46/50
# 63/63 - 8s - loss: 0.5991 - accuracy: 0.7836 - val_loss: 1.3716 - val_accuracy: 0.4231 - 8s/epoch - 126ms/step
# Epoch 47/50
# 63/63 - 7s - loss: 0.5249 - accuracy: 0.8196 - val_loss: 1.4624 - val_accuracy: 0.4423 - 7s/epoch - 109ms/step
# Epoch 48/50
# 63/63 - 9s - loss: 0.5574 - accuracy: 0.8216 - val_loss: 1.4445 - val_accuracy: 0.4615 - 9s/epoch - 137ms/step
# Epoch 49/50
# 63/63 - 7s - loss: 0.4900 - accuracy: 0.8116 - val_loss: 1.5361 - val_accuracy: 0.4808 - 7s/epoch - 106ms/step
# Epoch 50/50
# 63/63 - 8s - loss: 0.5389 - accuracy: 0.8216 - val_loss: 1.7438 - val_accuracy: 0.4423 - 8s/epoch - 125ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Flatten(),

    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(6, activation='softmax')
])

model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
)

# Jumlah epoch dapat dikustomisasi sesuai kebutuhan
# Out:
# Epoch 1/50
# 63/63 [==============================] - 13s 120ms/step - loss: 2.8855 - accuracy: 0.1723 - val_loss: 2.3210 - val_accuracy: 0.1923
# Epoch 2/50
# 63/63 [==============================] - 9s 131ms/step - loss: 2.4431 - accuracy: 0.2305 - val_loss: 4.2684 - val_accuracy: 0.1346
# Epoch 3/50
# 63/63 [==============================] - 7s 116ms/step - loss: 2.3482 - accuracy: 0.2405 - val_loss: 5.6167 - val_accuracy: 0.1346
# Epoch 4/50
# 63/63 [==============================] - 9s 136ms/step - loss: 2.2331 - accuracy: 0.2665 - val_loss: 4.7819 - val_accuracy: 0.1538
# Epoch 5/50
# 63/63 [==============================] - 8s 121ms/step - loss: 2.3206 - accuracy: 0.2204 - val_loss: 2.6635 - val_accuracy: 0.1538
# Epoch 6/50
# 63/63 [==============================] - 7s 117ms/step - loss: 2.1963 - accuracy: 0.2345 - val_loss: 3.5036 - val_accuracy: 0.1923
# Epoch 7/50
# 63/63 [==============================] - 7s 115ms/step - loss: 2.1533 - accuracy: 0.2645 - val_loss: 3.3065 - val_accuracy: 0.2115
# Epoch 8/50
# 63/63 [==============================] - 8s 130ms/step - loss: 2.0104 - accuracy: 0.2565 - val_loss: 2.1905 - val_accuracy: 0.2500
# Epoch 9/50
# 63/63 [==============================] - 8s 132ms/step - loss: 1.9819 - accuracy: 0.2585 - val_loss: 2.0499 - val_accuracy: 0.2885
# Epoch 10/50
# 63/63 [==============================] - 7s 109ms/step - loss: 2.0280 - accuracy: 0.2685 - val_loss: 2.2658 - val_accuracy: 0.3269
# Epoch 11/50
# 63/63 [==============================] - 8s 122ms/step - loss: 1.9658 - accuracy: 0.2465 - val_loss: 1.7120 - val_accuracy: 0.2885
# Epoch 12/50
# 63/63 [==============================] - 9s 136ms/step - loss: 1.9930 - accuracy: 0.2425 - val_loss: 1.7554 - val_accuracy: 0.3077
# Epoch 13/50
# 63/63 [==============================] - 8s 124ms/step - loss: 1.9413 - accuracy: 0.2305 - val_loss: 1.7272 - val_accuracy: 0.3077
# Epoch 14/50
# 63/63 [==============================] - 8s 126ms/step - loss: 1.8815 - accuracy: 0.2745 - val_loss: 1.7570 - val_accuracy: 0.2885
# Epoch 15/50
# 63/63 [==============================] - 8s 135ms/step - loss: 1.9162 - accuracy: 0.2485 - val_loss: 2.1367 - val_accuracy: 0.2308
# Epoch 16/50
# 63/63 [==============================] - 7s 116ms/step - loss: 1.8101 - accuracy: 0.3206 - val_loss: 1.9657 - val_accuracy: 0.2885
# Epoch 17/50
# 63/63 [==============================] - 8s 134ms/step - loss: 1.7956 - accuracy: 0.3246 - val_loss: 1.9225 - val_accuracy: 0.3077
# Epoch 18/50
# 63/63 [==============================] - 8s 130ms/step - loss: 1.7232 - accuracy: 0.3066 - val_loss: 1.9305 - val_accuracy: 0.1923
# Epoch 19/50
# 63/63 [==============================] - 7s 118ms/step - loss: 1.7799 - accuracy: 0.3206 - val_loss: 1.7729 - val_accuracy: 0.2115
# Epoch 20/50
# 63/63 [==============================] - 8s 134ms/step - loss: 1.7541 - accuracy: 0.3046 - val_loss: 1.6241 - val_accuracy: 0.3269
# Epoch 21/50
# 63/63 [==============================] - 8s 128ms/step - loss: 1.7949 - accuracy: 0.2986 - val_loss: 1.9809 - val_accuracy: 0.1346
# Epoch 22/50
# 63/63 [==============================] - 7s 115ms/step - loss: 1.8073 - accuracy: 0.2806 - val_loss: 1.6553 - val_accuracy: 0.3462
# Epoch 23/50
# 63/63 [==============================] - 8s 135ms/step - loss: 1.7846 - accuracy: 0.2926 - val_loss: 1.6866 - val_accuracy: 0.2885
# Epoch 24/50
# 63/63 [==============================] - 8s 131ms/step - loss: 1.7371 - accuracy: 0.2906 - val_loss: 1.6628 - val_accuracy: 0.3846
# Epoch 25/50
# 63/63 [==============================] - 7s 115ms/step - loss: 1.6890 - accuracy: 0.3206 - val_loss: 1.7411 - val_accuracy: 0.2885
# Epoch 26/50
# 63/63 [==============================] - 9s 137ms/step - loss: 1.7265 - accuracy: 0.3046 - val_loss: 1.7321 - val_accuracy: 0.3462
# Epoch 27/50
# 63/63 [==============================] - 8s 133ms/step - loss: 1.7228 - accuracy: 0.2986 - val_loss: 1.8426 - val_accuracy: 0.2500
# Epoch 28/50
# 63/63 [==============================] - 7s 107ms/step - loss: 1.6861 - accuracy: 0.3226 - val_loss: 1.7798 - val_accuracy: 0.3077
# Epoch 29/50
# 59/63 [===========================>..] - ETA: 0s - loss: 1.6644 - accuracy: 0.3105

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
